# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y,yp):
    mse = MSE = sum((y-yp)**2)/len(y)
    return MSE
    """
    請完成這個 Function 後往下執行
    """

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 272.725
# The Mean absolute error is 13.501

# %% [markdown]
# # [Homework1]
# 選擇題目：Google Play Store Apps
# 1. 你選的這組資料為何重要：因為現在美國禁止使用某些中國手機，使得在手機市場上有利於IPHONE以及Android系統的手機，若在APP使用上具有較多優勢者，則有機會提升銷售率。
# 2. 資料從何而來：擷取於APP應用程式中最相關的100條評論，並經過資料處裡歸納出主要因素。
# 3. 蒐集而來的資料型態為何：其為csv檔
# 4. 這組資料想解決的問題如何評估:Play商店應用數據具有巨大的潛力，然而許多公共數據集有堤共Apple App Store數據，但卻已找到Google Play的資料，因此此研究有助於讓消費者於受買手機時多一份評估資料。

# %% [markdown]
# # [Homework2]
# 題目：想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何：具有最高的經濟利潤，花最少時間轉取最大金額。
# 2. 資料從何而來：依照不同地區、族群以及加入車隊的差異性做網路調查
# 3. 蒐集而來的資料型態為何：利用GOOGLE表單轉成CSV檔。
# 4. 其如何評估：
#    a. 將資料經過出處理後進行分析，並得結論。
#    b. 最後可聯繫相關企業，如期結果受到肯定，並可驗證。
